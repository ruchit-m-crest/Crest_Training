# %%
pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/434.2 MB ? eta -:--:--
#      ---------------------------------------- 0.5/434.2 MB 3.0 MB/s eta 0:02:27
#      ---------------------------------------- 0.8/434.2 MB 2.3 MB/s eta 0:03:09
#      ---------------------------------------- 1.0/434.2 MB 1.7 MB/s eta 0:04:14
#      ---------------------------------------- 1.6/434.2 MB 1.7 MB/s eta 0:04:12
#      ---------------------------------------- 2.1/434.2 MB 1.9 MB/s eta 0:03:47
#      ---------------------------------------- 2.4/434.2 MB 1.8 MB/s eta 0:04:00
#      ---------------------------------------- 2.4/434.2 MB 1.8 MB/s eta 0:04:00
#      ---------------------------------------- 2.9/434.2 MB 1.6 MB/s eta 0:04:30
#      ---------------------------------------- 2.9/434.2 MB 1.6 MB/s eta 0:04:30
#      ---------------------------------------- 3.1/434.2 MB 1.4 MB/s eta 0:05:02
#      ---------------------------------------- 3.1/434.2 MB 1.4 MB/s eta 0:05:02
# ...

# %%
from pyspark import SparkContext
