# %%
#Gemini API 
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv(override=True)

GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)
response = gemini.chat.completions.create(model="gemini-2.5-flash-preview-05-20", messages=[{"role":"user", "content": "what is 2+2?"}])
print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
#OLLAMA API
from openai import OpenAI
MODEL = "llama3.2"
openai = OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")

response = openai.chat.completions.create(
 model=MODEL,
 messages=[{"role": "user", "content": "What is 2 + 2?"}]
)

print(response.choices[0].message.content)

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
google_api_key = os.getenv('GOOGLE_API_KEY')

if google_api_key:
    print(f"GOOGLE API Key exists and begins {google_api_key[:8]}")
else:
    print(" Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# GOOGLE API Key exists and begins AIzaSyCR

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
google_api_key = os.getenv("GOOGLE_API_KEY")
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses gemini-2.5-flash-preview-05-20

response = gemini.chat.completions.create(
    model="gemini-2.5-flash-preview-05-20",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# What number logically completes the sequence:
#
# 1, 3, 11, 43, 171, ?

# %%
# First create the messages:

messages = [{"role": "user", "content": "what is the capital of Gujarat?"}]

# Then make the first call:

response = gemini.chat.completions.create(
    model = "gemini-2.5-flash-preview-05-20",
    messages = messages
)


business_idea = response.choices[0].message.content

# %%
print(business_idea)
# Out:
# The capital of Gujarat is **Gandhinagar**.
