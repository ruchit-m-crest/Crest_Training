# %%
import os

# %%
os.environ.items()
# Out:
# ItemsView(environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'ANACONDA_NAVIGATOR_VERSION': '2.6.6', 'APPDATA': 'C:\\Users\\RuchitMeshiya\\AppData\\Roaming', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'RUCHIT-DESKTOP-', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONDA_DEFAULT_ENV': 'langchain_env', 'CONDA_EXE': 'C:\\Users\\RuchitMeshiya\\anaconda3\\Scripts\\conda.exe', 'CONDA_EXES': '"C:\\Users\\RuchitMeshiya\\anaconda3\\Scripts\\conda.exe"  ', 'CONDA_PREFIX': 'C:\\Users\\RuchitMeshiya\\anaconda3\\envs\\langchain_env', 'CONDA_PREFIX_1': 'C:\\Users\\RuchitMeshiya\\anaconda3', 'CONDA_PROMPT_MODIFIER': '(langchain_env) ', 'CONDA_PYTHON_EXE': 'C:\\Users\\RuchitMeshiya\\anaconda3\\python.exe', 'CONDA_ROOT': 'C:\\Users\\RuchitMeshiya\\anaconda3', 'CONDA_SHLVL': '2', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_17100_126
# ...

# %%
for  key,value in os.environ.items():
    if key == 'OPENAI_API_KEY':
        print(f"{key}:{value}")
# Out:
# OPENAI_API_KEY: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

# %%
# %reload_ext dotenv
# %dotenv
