# %% [markdown]
# ## 1. Generate a random alphabetical character, string and alphabetical strings of a fixed length

# %%
import random
import string

# %%
print("Generate a random alphabetical character:")
print(random.choice(string.ascii_letters))
print("\nGenerate a random alphabetical string:")
max_length = 255
str1 = ""
for i in range(random.randint(1, max_length)):
    str1 += random.choice(string.ascii_letters)
print(str1)
print("\nGenerate a random alphabetical string of a fixed length:")
str1 = ""
for i in range(10):
    str1 += random.choice(string.ascii_letters)
print(str1)
# Out:
# Generate a random alphabetical character:
# U
#
# Generate a random alphabetical string:
# yhTKZBYAPSiueDJzgzSZEvPEgiRruUJDaLxZhrUUVYeOTGvMFRwAsHcxbRwZIdkBLiHiCcmsyfrsefVmxQpKrOpsMIIMpUHzfkDHMqaShlYBDRApQxkuGGMWAOvbnoLbMKpgwNKJwXdBntviMuaaJvKJHOQ
#
# Generate a random alphabetical string of a fixed length:
# dAfYSyxnaR

# %% [markdown]
# ## 2.Count number of lines in a CSV file

# %%
import csv

# %%
reader = csv.reader(open('weekday.csv'))
no_lines = len(list(reader))
print(no_lines)
# Out:
# 8
