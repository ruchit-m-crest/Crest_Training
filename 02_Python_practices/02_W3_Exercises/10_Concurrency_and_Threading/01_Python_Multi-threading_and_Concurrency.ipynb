# %% [markdown]
# ## 1. Program to perform concurrent HTTP requests using threads

# %%
import requests
import threading

# %%
def make_request(url):
    response =  requests.get(url)
    print(f'Response from {url}: {response.status_code}')

urls = [
    'https://www.example.com',
    'https://www.google.com'
]

threads = []

for url in urls:
    thread = threading.Thread(target=make_request, args=(url,))
    thread.start()
    threads.append(thread)

for thread in threads:
    thread.join()
# Out:
# Response from https://www.example.com: 200
# Response from https://www.google.com: 200

# %% [markdown]
# ## 2. program to create multiple threads and print their names

# %%
import threading
def print_thread_names():
    print("Current thread name:", threading.current_thread().name)

threads = []
for i in range(7):
    thread = threading.Thread(target=print_thread_names)
    threads.append(thread)
    thread.start()

for thread in threads:
    thread.join()
# Out:
# Current thread name: Thread-21 (print_thread_names)
# Current thread name: Thread-22 (print_thread_names)
# Current thread name: Thread-23 (print_thread_names)
# Current thread name: Thread-24 (print_thread_names)
# Current thread name: Thread-25 (print_thread_names)
# Current thread name: Thread-26 (print_thread_names)
# Current thread name: Thread-27 (print_thread_names)
