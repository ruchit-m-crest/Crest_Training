# %%
pip install pendulum
# Out:
# Collecting pendulum
#   Downloading pendulum-3.1.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: python-dateutil>=2.6 in c:\users\ruchitmeshiya\anaconda3\lib\site-packages (from pendulum) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2020.1 in c:\users\ruchitmeshiya\anaconda3\lib\site-packages (from pendulum) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ruchitmeshiya\anaconda3\lib\site-packages (from python-dateutil>=2.6->pendulum) (1.17.0)
# Downloading pendulum-3.1.0-cp313-cp313-win_amd64.whl (260 kB)
# Installing collected packages: pendulum
# Successfully installed pendulum-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1.Program to round current time to the nearest hour using pendulum module

# %%
import pendulum

current_datetime = pendulum.now()

rounded_datetime = current_datetime.start_of('hour')

print('Rounded time ot the  nearest hour:,'
# Out:
# current date and time : 2025-07-24 12:28:39.039872+05:30

# %% [markdown]
# ## 2.Program to calculate and print the travel time between two given dates and times them using Pendulum module.

# %%
import pendulum

def calculate_travel_time(start_datetime, end_datetime):
    travel_time = start_datetime.diff(end_datetime)

    print(f"Travel time from {start_datetime} to {end_datetime}: {travel_time.in_words()}")

start_datetime_str = "2023-06-01 12:30:00"
end_datetime_str = "2023-06-02 15:45:00"

start_datetime = pendulum.parse(start_datetime_str)
end_datetime = pendulum.parse(end_datetime_str)

calculate_travel_time(start_datetime, end_datetime)
# Out:
# Travel time from 2023-06-01 12:30:00+00:00 to 2023-06-02 15:45:00+00:00: 1 day 3 hours 15 minutes
