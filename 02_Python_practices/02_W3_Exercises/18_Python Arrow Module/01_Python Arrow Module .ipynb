# %%
import arrow
a = arrow.utcnow()
print("Current datetime:")
print(a)
print("\ntime.struct_time, in the current timezone:")
print(arrow.utcnow().timetuple())
# Out:
# Current datetime:
# 2025-07-28T08:46:45.970136+00:00
#
# time.struct_time, in the current timezone:
# time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=8, tm_min=46, tm_sec=45, tm_wday=0, tm_yday=209, tm_isdst=0)
