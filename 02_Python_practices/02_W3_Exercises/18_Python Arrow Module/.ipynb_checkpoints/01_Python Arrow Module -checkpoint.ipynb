# %%
pip install arror
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement arror (from versions: none)
# ERROR: No matching distribution found for arror

# %%
import arrow

print("Test whether a given datetime is between two dates and times:")
start = arrow.get(datetime(2017, 6, 5, 12, 30, 10))
end = arrow.get(datetime(2017, 6, 5, 12, 30, 36))
print(arrow.get(datetime(2017, 6, 5, 12, 30, 27)).is_between(start, end))
start = arrow.get(datetime(2017, 5, 5))
end = arrow.get(datetime(2017, 5, 8))
print(arrow.get(datetime(2017, 5, 8)).is_between(start, end, '[]'))
start = arrow.get(datetime(2017, 5, 5))
# Out:
# Test whether a given datetime is between two dates and times:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import arrow
#       3 print("Test whether a given datetime is between two dates and times:")
# ----> 4 start = arrow.get(datetime(2017, 6, 5, 12, 30, 10))
#       5 end = arrow.get(datetime(2017, 6, 5, 12, 30, 36))
#       6 print(arrow.get(datetime(2017, 6, 5, 12, 30, 27)).is_between(start, end))
#
# NameError: name 'datetime' is not defined
