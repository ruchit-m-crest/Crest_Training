# %% [markdown]
# ## 1. Implement a decorator to measure memory usage of a function

# %%
import tracemalloc

def measure_memory_usage(func):
    def wrapper(*args, **kwargs):
        tracemalloc.start()

        # Call the original function
        result = func(*args, **kwargs)

        snapshot = tracemalloc.take_snapshot()
        top_stats = snapshot.statistics("lineno")

        # Print the top memory-consuming lines
        print(f"Memory usage of {func.__name__}:")
        for stat in top_stats[:5]:
            print(stat)

        # Return the result
        return result

    return wrapper

# Example usage
@measure_memory_usage
def calculate_factorial(n):
    if n == 0:
        return 1
    else:
        return n * calculate_factorial(n - 1)

# Call the decorated function
result = calculate_factorial(5)
print("Factorial:", result)
# Out:
# Memory usage of calculate_factorial:
# C:\Users\RuchitMeshiya\AppData\Local\Temp\ipykernel_22816\4278932499.py:29: size=192 B, count=4, average=48 B
# Memory usage of calculate_factorial:
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:684: size=1390 B, count=7, average=199 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:587: size=208 B, count=2, average=104 B
# C:\Users\RuchitMeshiya\AppData\Local\Temp\ipykernel_22816\4278932499.py:29: size=192 B, count=4, average=48 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:207: size=48 B, count=1, average=48 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:193: size=48 B, count=1, average=48 B
# Memory usage of calculate_factorial:
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:684: size=1951 B, count=7, average=279 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:193: size=336 B, count=7, average=48 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:67: size=320 B, count=5, average=64 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:587: size=208 B, count=2, average=104 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:558: size=192 B, count=4, average=48 B
# Memory usage of calculate_factorial:
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:684: size=2447 B, count=7, average=350 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:558: size=384 B, count=8, average=48 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:67: size=384 B, count=6, average=64 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:193: size=336 B, count=7, average=48 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:587: size=208 B, count=2, average=104 B
# Memory usage of calculate_factorial:
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:684: size=3251 B, count=7, average=464 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:558: size=480 B, count=10, average=48 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:67: size=448 B, count=7, average=64 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:193: size=288 B, count=6, average=48 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:587: size=208 B, count=2, average=104 B
# Memory usage of calculate_factorial:
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:684: size=4328 B, count=7, average=618 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:67: size=448 B, count=7, average=64 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:193: size=432 B, count=9, average=48 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\tracemalloc.py:558: size=336 B, count=7, average=48 B
# C:\Users\RuchitMeshiya\anaconda3\Lib\site-packages\ipykernel\iostream.py:587: size=208 B, count=2, average=104 B
# Factorial: 120
